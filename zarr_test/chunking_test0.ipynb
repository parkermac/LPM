# %%
import xarray as xr
from lo_tools import Lfun
Ldir = Lfun.Lstart()
Ldir
# Out:
# {'lo_env': 'pm_mac',
#  'parent': PosixPath('/Users/parkermaccready/Documents'),
#  'LO': PosixPath('/Users/parkermaccready/Documents/LO'),
#  'LOo': PosixPath('/Users/parkermaccready/Documents/LO_output'),
#  'LOu': PosixPath('/Users/parkermaccready/Documents/LO_user'),
#  'data': PosixPath('/Users/parkermaccready/Documents/LO_data'),
#  'roms_out': PosixPath('/Users/parkermaccready/Documents/LO_roms'),
#  'roms_out1': PosixPath('/Users/parkermaccready/Documents/BLANK'),
#  'roms_out2': PosixPath('/Users/parkermaccready/Documents/BLANK'),
#  'roms_out3': PosixPath('/Users/parkermaccready/Documents/BLANK'),
#  'roms_out4': PosixPath('/Users/parkermaccready/Documents/BLANK'),
#  'remote_user': 'BLANK',
#  'remote_machine': 'BLANK',
#  'remote_dir0': 'BLANK',
#  'local_user': 'BLANK',
#  'traps_name': 'traps00',
#  'gridname': 'BLANK',
#  'tag': 'BLANK',
#  'ex_name': 'BLANK',
#  'gtag': 'BLANK_BLANK',
#  'gtagex': 'BLANK_BLANK_BLANK',
# ...

# %%
in_dir = Ldir['roms_out'] / 'cas7_t1_x11b' / 'f2025.06.20'
out_dir = Ldir['parent'] / 'LPM_output' / 'zarr_test'
Lfun.make_dir(out_dir)

# %%
ds = xr.open_mfdataset(str(in_dir) + '/ocean_his*.nc')
# Out:
# /var/folders/31/rhr_qv2x2v1bjlwbnmm89lth0000gn/T/ipykernel_56122/1841227541.py:1: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(str(in_dir) + '/ocean_his*.nc')

# %%
out_fn = out_dir / 'test0.zarr'
ds.to_zarr(out_fn, mode='w')
# Out:
# /Users/parkermaccready/miniconda3/envs/loenv/lib/python3.12/site-packages/zarr/api/asynchronous.py:231: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(

# %%
dsz = xr.open_zarr(out_fn)

# %%
dsz.salt
# Out:
# <xarray.DataArray 'salt' (ocean_time: 25, s_rho: 30, eta_rho: 1302, xi_rho: 663)> Size: 3GB
# dask.array<open_dataset-salt, shape=(25, 30, 1302, 663), dtype=float32, chunksize=(1, 8, 434, 221), chunktype=numpy.ndarray>
# Coordinates:
#   * ocean_time  (ocean_time) datetime64[ns] 200B 2025-06-20 ... 2025-06-21
#   * s_rho       (s_rho) float64 240B -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#     lat_rho     (eta_rho, xi_rho) float64 7MB dask.array<chunksize=(651, 332), meta=np.ndarray>
#     lon_rho     (eta_rho, xi_rho) float64 7MB dask.array<chunksize=(651, 332), meta=np.ndarray>
# Dimensions without coordinates: eta_rho, xi_rho
# Attributes:
#     standard_name:  sea_water_practical_salinity
#     long_name:      salinity
#     time:           ocean_time
#     cell_methods:   ocean_time: point
#     grid:           grid
#     location:       face
#     field:          salinity
